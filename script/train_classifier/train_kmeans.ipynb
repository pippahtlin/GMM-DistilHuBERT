# %% [markdown]
# # K-Means Training on DistilHuBERT Layer Features
# 500-cluster K-Means model on concatenated outputs from the first three layers of the fine-tuned DistilHuBERT model (step1)
# * 1000 batch

# %%
import sys
sys.executable

import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %%
import os
import torch
import numpy as np
from datasets import load_dataset, Audio,load_dataset, DownloadConfig
from transformers import AutoProcessor, AutoModel
from sklearn.cluster import MiniBatchKMeans
from train_classifier import extract_all_layer_features

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModel.from_pretrained("/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/checkpoints_distilhubert_asr/final_model").to(device)
processor = AutoProcessor.from_pretrained("/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/checkpoints_distilhubert_asr/final_model")

# %%
# Config
num_clusters = 500
layers = [0, 1, 2]
batch_size = 32  # # of audio samples processed at once
max_batches = 1000  # safeguard against too much data (optional)

# %%
dataset = load_dataset("audiofolder", 
                       data_dir="/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/data/LibriSpeech/train-other-500")["train"]
dataset = dataset.cast_column("audio", Audio(sampling_rate=16000))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dataset = load_dataset(
#       2     "audiofolder",
#       3     data_dir="/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/data/LibriSpeech/train-other-500"
#       4 )["train"]
#       6 dataset = dataset.cast_column("audio", Audio(sampling_rate=16000))
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/load.py:2062, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2057 verification_mode = VerificationMode(
#    2058     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2059 )
#    2061 # Create a dataset builder
# -> 2062 builder_instance = load_dataset_builder(
#    2063     path=path,
#    2064     name=name,
#    2065     data_dir=data_dir,
#    2066     data_files=data_files,
#    2067     cache_dir=cache_dir,
#    2068     features=features,
#    2069     download_config=download_config,
#    2070     download_mode=download_mode,
#    2071     revision=revision,
#    2072     token=token,
#    2073     storage_options=storage_options,
#    2074     trust_remote_code=trust_remote_code,
#    2075     _require_default_config_name=name is None,
#    2076     **config_kwargs,
#    2077 )
#    2079 # Return iterable dataset in case of streaming
#    2080 if streaming:
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/load.py:1782, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1780     download_config = download_config.copy() if download_config else DownloadConfig()
#    1781     download_config.storage_options.update(storage_options)
# -> 1782 dataset_module = dataset_module_factory(
#    1783     path,
#    1784     revision=revision,
#    1785     download_config=download_config,
#    1786     download_mode=download_mode,
#    1787     data_dir=data_dir,
#    1788     data_files=data_files,
#    1789     cache_dir=cache_dir,
#    1790     trust_remote_code=trust_remote_code,
#    1791     _require_default_config_name=_require_default_config_name,
#    1792     _require_custom_configs=bool(config_kwargs),
#    1793 )
#    1794 # Get dataset builder class from the processing script
#    1795 builder_kwargs = dataset_module.builder_kwargs
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/load.py:1497, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1474 # We have several ways to get a dataset builder:
#    1475 #
#    1476 # - if path is the name of a packaged dataset module
#    (...)
#    1488
#    1489 # Try packaged
#    1490 if path in _PACKAGED_DATASETS_MODULES:
#    1491     return PackagedDatasetModuleFactory(
#    1492         path,
#    1493         data_dir=data_dir,
#    1494         data_files=data_files,
#    1495         download_config=download_config,
#    1496         download_mode=download_mode,
# -> 1497     ).get_module()
#    1498 # Try locally
#    1499 elif path.endswith(filename):
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/load.py:911, in PackagedDatasetModuleFactory.get_module(self)
#     906 def get_module(self) -> DatasetModule:
#     907     base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     908     patterns = (
#     909         sanitize_patterns(self.data_files)
#     910         if self.data_files is not None
# --> 911         else get_data_patterns(base_path, download_config=self.download_config)
#     912     )
#     913     data_files = DataFilesDict.from_patterns(
#     914         patterns,
#     915         download_config=self.download_config,
#     916         base_path=base_path,
#     917     )
#     919     module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/data_files.py:473, in get_data_patterns(base_path, download_config)
#     471 resolver = partial(resolve_pattern, base_path=base_path, download_config=download_config)
#     472 try:
# --> 473     return _get_data_files_patterns(resolver)
#     474 except FileNotFoundError:
#     475     raise EmptyDatasetError(f"The directory at {base_path} doesn't contain any data files") from None
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/data_files.py:284, in _get_data_files_patterns(pattern_resolver)
#     282 for pattern in patterns:
#     283     try:
# --> 284         data_files = pattern_resolver(pattern)
#     285     except FileNotFoundError:
#     286         continue
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/datasets/data_files.py:360, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     355 if protocol == "hf" and config.HF_HUB_VERSION >= version.parse("0.20.0"):
#     356     # 10 times faster glob with detail=True (ignores costly info like lastCommit)
#     357     glob_kwargs["expand_info"] = False
#     358 matched_paths = [
#     359     filepath if filepath.startswith(protocol_prefix) else protocol_prefix + filepath
# --> 360     for filepath, info in fs.glob(pattern, detail=True, **glob_kwargs).items()
#     361     if (info["type"] == "file" or (info.get("islink") and os.path.isfile(os.path.realpath(filepath))))
#     362     and (xbasename(filepath) not in files_to_ignore)
#     363     and not _is_inside_unrequested_special_dir(filepath, fs_pattern)
#     364     and not _is_unrequested_hidden_file_or_is_inside_unrequested_hidden_dir(filepath, fs_pattern)
#     365 ]  # ignore .ipynb and __pycache__, but keep /../
#     366 if allowed_extensions is not None:
#     367     out = [
#     368         filepath
#     369         for filepath in matched_paths
#     370         if any("." + suffix in allowed_extensions for suffix in xbasename(filepath).split(".")[1:])
#     371     ]
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/fsspec/spec.py:614, in AbstractFileSystem.glob(self, path, maxdepth, **kwargs)
#     611 pattern = glob_translate(path + ("/" if ends_with_sep else ""))
#     612 pattern = re.compile(pattern)
# --> 614 out = {
#     615     p: info
#     616     for p, info in sorted(allpaths.items())
#     617     if pattern.match(
#     618         p + "/"
#     619         if append_slash_to_dirname and info["type"] == "directory"
#     620         else p
#     621     )
#     622 }
#     624 if detail:
#     625     return out
#
# File /share/data/lang/users/ttic_31110/GMM_DHuBERT/mc3/envs/gmm-hubert/lib/python3.10/site-packages/fsspec/spec.py:619, in <dictcomp>(.0)
#     611 pattern = glob_translate(path + ("/" if ends_with_sep else ""))
#     612 pattern = re.compile(pattern)
#     614 out = {
#     615     p: info
#     616     for p, info in sorted(allpaths.items())
#     617     if pattern.match(
#     618         p + "/"
# --> 619         if append_slash_to_dirname and info["type"] == "directory"
#     620         else p
#     621     )
#     622 }
#     624 if detail:
#     625     return out
#
# KeyboardInterrupt:

# %% [markdown]
# #### test on a small batch

# %%
dataset = load_dataset(
    "audiofolder",
    data_dir="/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/data/LibriSpeech/train-other-500/3885/1193"
)["train"]  # 👈 get the 'train' split from the dataset dict

print("Loaded dataset:", len(dataset))
print("Example:", dataset[0])

dataset = dataset.cast_column("audio", Audio(sampling_rate=16000))

all_features = []

for example in dataset:  # e.g., loaded using "audiofolder"
    waveform = processor(example["audio"]["array"], sampling_rate=16000, return_tensors="pt").input_values.to(device)
    feats = extract_all_layer_features(model, waveform, layers=[0, 1, 2])
    all_features.append(feats.squeeze(0).cpu().numpy())  # [T, D]

# Combine for clustering
all_feats = np.vstack(all_features)  # [total_T, D]
kmeans = MiniBatchKMeans(n_clusters=500, batch_size=2048)
kmeans.fit(all_feats)

print("Cluster centers shape:", kmeans.cluster_centers_.shape)  # Should be [500, D]
test_feats = extract_all_layer_features(model, waveform, layers=[0,1,2]).squeeze(0).cpu().numpy()
cluster_ids = kmeans.predict(test_feats)  # shape [T]
print(cluster_ids[:20])

# %%
print("Type of dataset:", type(dataset))
print("Sample audio entry:", dataset[0]["audio"])
# Out:
# Type of dataset: <class 'datasets.arrow_dataset.Dataset'>
# Sample audio entry: {'path': '/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/data/LibriSpeech/train-other-500/1006/135212/1006-135212-0000.flac', 'array': array([0.04141235, 0.04229736, 0.04345703, ..., 0.03570557, 0.03594971,
#        0.03588867]), 'sampling_rate': 16000}

# %%
'''
# Initialize KMeans
kmeans = MiniBatchKMeans(n_clusters=num_clusters, batch_size=2048)

# Incrementally feed KMeans
batch_count = 0
for i in range(0, len(dataset), batch_size):
    batch = dataset.select(range(i, min(i + batch_size, len(dataset))))
    feats_batch = []

    for example in batch:
        audio = example["audio"]
        input_values = processor(audio["array"], sampling_rate=16000, return_tensors="pt").input_values.to(device)
        features = extract_all_layer_features(model, input_values, layers=layers)
        feats_batch.append(features.squeeze(0).cpu().numpy())

    all_feats = np.vstack(feats_batch)
    kmeans.partial_fit(all_feats)
    all_feats = np.vstack(feats_batch)  # shape [total_T, D]
    kmeans.partial_fit(all_feats)  # update centroids

    batch_count += 1
    print(f"Processed batch {batch_count}, features shape: {all_feats.shape}")

    if batch_count >= max_batches:
        print("Reached max batch limit. Stopping early.")
        break
'''
# Out:
# Processed batch 1, features shape: (21580, 2304)
# Processed batch 2, features shape: (20856, 2304)
# Processed batch 3, features shape: (18893, 2304)
# Processed batch 4, features shape: (21753, 2304)
# Processed batch 5, features shape: (21415, 2304)
# Processed batch 6, features shape: (20193, 2304)
# Processed batch 7, features shape: (14600, 2304)
# Processed batch 8, features shape: (15208, 2304)
# Processed batch 9, features shape: (17387, 2304)
# Processed batch 10, features shape: (14246, 2304)
# Processed batch 11, features shape: (15522, 2304)
# Processed batch 12, features shape: (17825, 2304)
# Processed batch 13, features shape: (19143, 2304)
# Processed batch 14, features shape: (18272, 2304)
# Processed batch 15, features shape: (18724, 2304)
# Processed batch 16, features shape: (18361, 2304)
# Processed batch 17, features shape: (19963, 2304)
# Processed batch 18, features shape: (17888, 2304)
# Processed batch 19, features shape: (15600, 2304)
# Processed batch 20, features shape: (16079, 2304)
# Processed batch 21, features shape: (15593, 2304)
# Processed batch 22, features shape: (16321, 2304)
# Processed batch 23, features shape: (18188, 2304)
# Processed batch 24, features shape: (20174, 2304)
# Processed batch 25, features shape: (20215, 2304)
# Processed batch 26, features shape: (17513, 2304)
# Processed batch 27, features shape: (20603, 2304)
# Processed batch 28, features shape: (20776, 2304)
# Processed batch 29, features shape: (20357, 2304)
# Processed batch 30, features shape: (21582, 2304)
# Processed batch 31, features shape: (17557, 2304)
# Processed batch 32, features shape: (18781, 2304)
# Processed batch 33, features shape: (18885, 2304)
# Processed batch 34, features shape: (19157, 2304)
# Processed batch 35, features shape: (21489, 2304)
# Processed batch 36, features shape: (19857, 2304)
# Processed batch 37, features shape: (21137, 2304)
# Processed batch 38, features shape: (19815, 2304)
# Processed batch 39, features shape: (21432, 2304)
# Processed batch 40, features shape: (19805, 2304)
# Processed batch 41, features shape: (18067, 2304)
# Processed batch 42, features shape: (19480, 2304)
# Processed batch 43, features shape: (19049, 2304)
# Processed batch 44, features shape: (18950, 2304)
# Processed batch 45, features shape: (17648, 2304)
# Processed batch 46, features shape: (17622, 2304)
# Processed batch 47, features shape: (20155, 2304)
# Processed batch 48, features shape: (19907, 2304)
# Processed batch 49, features shape: (21854, 2304)
# Processed batch 50, features shape: (22117, 2304)
# Processed batch 51, features shape: (19868, 2304)
# Processed batch 52, features shape: (16812, 2304)
# Processed batch 53, features shape: (21814, 2304)
# Processed batch 54, features shape: (21916, 2304)
# Processed batch 55, features shape: (22832, 2304)
# Processed batch 56, features shape: (20441, 2304)
# Processed batch 57, features shape: (20742, 2304)
# Processed batch 58, features shape: (21762, 2304)
# Processed batch 59, features shape: (20713, 2304)
# Processed batch 60, features shape: (21387, 2304)
# Processed batch 61, features shape: (19379, 2304)
# Processed batch 62, features shape: (15636, 2304)
# Processed batch 63, features shape: (15608, 2304)
# Processed batch 64, features shape: (17647, 2304)
# Processed batch 65, features shape: (18775, 2304)
# Processed batch 66, features shape: (19455, 2304)
# Processed batch 67, features shape: (19716, 2304)
# Processed batch 68, features shape: (18154, 2304)
# Processed batch 69, features shape: (20432, 2304)
# Processed batch 70, features shape: (17770, 2304)
# Processed batch 71, features shape: (20815, 2304)
# Processed batch 72, features shape: (17612, 2304)
# Processed batch 73, features shape: (19029, 2304)
# Processed batch 74, features shape: (15534, 2304)
# Processed batch 75, features shape: (17698, 2304)
# Processed batch 76, features shape: (19350, 2304)
# Processed batch 77, features shape: (21485, 2304)
# Processed batch 78, features shape: (21622, 2304)
# Processed batch 79, features shape: (21611, 2304)
# Processed batch 80, features shape: (19227, 2304)
# Processed batch 81, features shape: (22461, 2304)
# Processed batch 82, features shape: (21281, 2304)
# Processed batch 83, features shape: (23080, 2304)
# Processed batch 84, features shape: (22139, 2304)
# Processed batch 85, features shape: (22220, 2304)
# Processed batch 86, features shape: (20192, 2304)
# Processed batch 87, features shape: (15909, 2304)
# Processed batch 88, features shape: (14674, 2304)
# Processed batch 89, features shape: (16967, 2304)
# Processed batch 90, features shape: (18459, 2304)
# Processed batch 91, features shape: (18651, 2304)
# Processed batch 92, features shape: (18329, 2304)
# Processed batch 93, features shape: (16257, 2304)
# Processed batch 94, features shape: (13416, 2304)
# Processed batch 95, features shape: (16012, 2304)
# Processed batch 96, features shape: (20229, 2304)
# Processed batch 97, features shape: (22725, 2304)
# Processed batch 98, features shape: (20886, 2304)
# Processed batch 99, features shape: (21874, 2304)
# Processed batch 100, features shape: (17354, 2304)
# Processed batch 101, features shape: (15127, 2304)
# Processed batch 102, features shape: (18120, 2304)
# Processed batch 103, features shape: (21557, 2304)
# Processed batch 104, features shape: (20413, 2304)
# Processed batch 105, features shape: (22761, 2304)
# Processed batch 106, features shape: (22295, 2304)
# Processed batch 107, features shape: (20450, 2304)
# Processed batch 108, features shape: (18483, 2304)
# Processed batch 109, features shape: (20536, 2304)
# Processed batch 110, features shape: (21197, 2304)
# Processed batch 111, features shape: (20445, 2304)
# Processed batch 112, features shape: (15972, 2304)
# Processed batch 113, features shape: (16567, 2304)
# Processed batch 114, features shape: (17802, 2304)
# Processed batch 115, features shape: (18320, 2304)
# Processed batch 116, features shape: (17902, 2304)
# Processed batch 117, features shape: (15593, 2304)
# Processed batch 118, features shape: (15432, 2304)
# Processed batch 119, features shape: (17728, 2304)
# Processed batch 120, features shape: (19459, 2304)
# Processed batch 121, features shape: (16797, 2304)
# Processed batch 122, features shape: (17843, 2304)
# Processed batch 123, features shape: (14566, 2304)
# Processed batch 124, features shape: (16708, 2304)
# Processed batch 125, features shape: (13496, 2304)
# Processed batch 126, features shape: (18721, 2304)
# Processed batch 127, features shape: (20196, 2304)
# Processed batch 128, features shape: (18836, 2304)
# Processed batch 129, features shape: (19085, 2304)
# Processed batch 130, features shape: (20056, 2304)
# Processed batch 131, features shape: (22141, 2304)
# Processed batch 132, features shape: (18469, 2304)
# Processed batch 133, features shape: (16796, 2304)
# Processed batch 134, features shape: (17638, 2304)
# Processed batch 135, features shape: (21003, 2304)
# Processed batch 136, features shape: (16442, 2304)
# Processed batch 137, features shape: (12594, 2304)
# Processed batch 138, features shape: (17277, 2304)
# Processed batch 139, features shape: (17107, 2304)
# Processed batch 140, features shape: (18441, 2304)
# Processed batch 141, features shape: (13093, 2304)
# Processed batch 142, features shape: (22060, 2304)
# Processed batch 143, features shape: (21700, 2304)
# Processed batch 144, features shape: (22470, 2304)
# Processed batch 145, features shape: (20630, 2304)
# Processed batch 146, features shape: (21487, 2304)
# Processed batch 147, features shape: (16973, 2304)
# Processed batch 148, features shape: (22564, 2304)
# Processed batch 149, features shape: (17729, 2304)
# Processed batch 150, features shape: (16620, 2304)
# Processed batch 151, features shape: (16251, 2304)
# Processed batch 152, features shape: (21840, 2304)
# Processed batch 153, features shape: (21262, 2304)
# Processed batch 154, features shape: (21222, 2304)
# Processed batch 155, features shape: (18518, 2304)
# Processed batch 156, features shape: (16422, 2304)
# Processed batch 157, features shape: (20622, 2304)
# Processed batch 158, features shape: (17508, 2304)
# Processed batch 159, features shape: (17284, 2304)
# Processed batch 160, features shape: (20328, 2304)
# Processed batch 161, features shape: (19053, 2304)
# Processed batch 162, features shape: (22146, 2304)
# Processed batch 163, features shape: (21277, 2304)
# Processed batch 164, features shape: (21316, 2304)
# Processed batch 165, features shape: (18963, 2304)
# Processed batch 166, features shape: (9270, 2304)
# Processed batch 167, features shape: (13691, 2304)
# Processed batch 168, features shape: (12908, 2304)
# Processed batch 169, features shape: (11372, 2304)
# Processed batch 170, features shape: (11213, 2304)
# Processed batch 171, features shape: (11335, 2304)
# Processed batch 172, features shape: (11724, 2304)
# Processed batch 173, features shape: (18777, 2304)
# Processed batch 174, features shape: (19124, 2304)
# Processed batch 175, features shape: (16843, 2304)
# Processed batch 176, features shape: (17649, 2304)
# Processed batch 177, features shape: (19206, 2304)
# Processed batch 178, features shape: (18336, 2304)
# Processed batch 179, features shape: (20020, 2304)
# Processed batch 180, features shape: (20919, 2304)
# Processed batch 181, features shape: (20630, 2304)
# Processed batch 182, features shape: (21880, 2304)
# Processed batch 183, features shape: (20678, 2304)
# Processed batch 184, features shape: (18062, 2304)
# Processed batch 185, features shape: (20046, 2304)
# Processed batch 186, features shape: (20442, 2304)
# Processed batch 187, features shape: (21736, 2304)
# Processed batch 188, features shape: (19577, 2304)
# Processed batch 189, features shape: (22443, 2304)
# Processed batch 190, features shape: (21888, 2304)
# Processed batch 191, features shape: (22374, 2304)
# Processed batch 192, features shape: (17441, 2304)
# Processed batch 193, features shape: (20034, 2304)
# Processed batch 194, features shape: (19794, 2304)
# Processed batch 195, features shape: (17463, 2304)
# Processed batch 196, features shape: (20024, 2304)
# Processed batch 197, features shape: (21954, 2304)
# Processed batch 198, features shape: (19705, 2304)
# Processed batch 199, features shape: (22540, 2304)
# Processed batch 200, features shape: (22167, 2304)
# Processed batch 201, features shape: (20117, 2304)
# Processed batch 202, features shape: (20120, 2304)
# Processed batch 203, features shape: (20939, 2304)
# Processed batch 204, features shape: (20099, 2304)
# Processed batch 205, features shape: (20109, 2304)
# Processed batch 206, features shape: (19729, 2304)
# Processed batch 207, features shape: (21505, 2304)
# Processed batch 208, features shape: (20435, 2304)
# Processed batch 209, features shape: (19287, 2304)
# Processed batch 210, features shape: (18942, 2304)
# Processed batch 211, features shape: (16546, 2304)
# Processed batch 212, features shape: (20362, 2304)
# Processed batch 213, features shape: (18113, 2304)
# Processed batch 214, features shape: (18651, 2304)
# Processed batch 215, features shape: (21610, 2304)
# Processed batch 216, features shape: (20453, 2304)
# Processed batch 217, features shape: (21384, 2304)
# Processed batch 218, features shape: (19116, 2304)
# Processed batch 219, features shape: (20396, 2304)
# Processed batch 220, features shape: (21682, 2304)
# Processed batch 221, features shape: (20325, 2304)
# Processed batch 222, features shape: (19745, 2304)
# Processed batch 223, features shape: (21111, 2304)
# Processed batch 224, features shape: (18137, 2304)
# Processed batch 225, features shape: (18421, 2304)
# Processed batch 226, features shape: (20626, 2304)
# Processed batch 227, features shape: (19001, 2304)
# Processed batch 228, features shape: (18186, 2304)
# Processed batch 229, features shape: (21163, 2304)
# Processed batch 230, features shape: (20871, 2304)
# Processed batch 231, features shape: (20385, 2304)
# Processed batch 232, features shape: (20682, 2304)
# Processed batch 233, features shape: (18972, 2304)
# Processed batch 234, features shape: (19275, 2304)
# Processed batch 235, features shape: (22822, 2304)
# Processed batch 236, features shape: (21853, 2304)
# Processed batch 237, features shape: (19242, 2304)
# Processed batch 238, features shape: (18983, 2304)
# Processed batch 239, features shape: (18901, 2304)
# Processed batch 240, features shape: (20787, 2304)
# Processed batch 241, features shape: (19254, 2304)
# Processed batch 242, features shape: (18726, 2304)
# Processed batch 243, features shape: (18203, 2304)
# Processed batch 244, features shape: (17127, 2304)
# Processed batch 245, features shape: (12908, 2304)
# Processed batch 246, features shape: (17889, 2304)
# Processed batch 247, features shape: (19512, 2304)
# Processed batch 248, features shape: (15538, 2304)
# Processed batch 249, features shape: (13363, 2304)
# Processed batch 250, features shape: (8693, 2304)
# Processed batch 251, features shape: (9945, 2304)
# Processed batch 252, features shape: (14387, 2304)
# Processed batch 253, features shape: (20809, 2304)
# Processed batch 254, features shape: (19810, 2304)
# Processed batch 255, features shape: (19145, 2304)
# Processed batch 256, features shape: (22743, 2304)
# Processed batch 257, features shape: (16823, 2304)
# Processed batch 258, features shape: (21029, 2304)
# Processed batch 259, features shape: (17476, 2304)
# Processed batch 260, features shape: (20896, 2304)
# Processed batch 261, features shape: (10557, 2304)
# Processed batch 262, features shape: (10036, 2304)
# Processed batch 263, features shape: (11641, 2304)
# Processed batch 264, features shape: (11642, 2304)
# Processed batch 265, features shape: (12000, 2304)
# Processed batch 266, features shape: (20861, 2304)
# Processed batch 267, features shape: (19362, 2304)
# Processed batch 268, features shape: (21272, 2304)
# Processed batch 269, features shape: (21644, 2304)
# Processed batch 270, features shape: (20340, 2304)
# Processed batch 271, features shape: (18471, 2304)
# Processed batch 272, features shape: (18800, 2304)
# Processed batch 273, features shape: (19558, 2304)
# Processed batch 274, features shape: (18869, 2304)
# Processed batch 275, features shape: (20144, 2304)
# Processed batch 276, features shape: (21270, 2304)
# Processed batch 277, features shape: (20534, 2304)
# Processed batch 278, features shape: (19267, 2304)
# Processed batch 279, features shape: (10643, 2304)
# Processed batch 280, features shape: (14636, 2304)
# Processed batch 281, features shape: (20296, 2304)
# Processed batch 282, features shape: (20655, 2304)
# Processed batch 283, features shape: (21788, 2304)
# Processed batch 284, features shape: (19955, 2304)
# Processed batch 285, features shape: (19578, 2304)
# Processed batch 286, features shape: (18089, 2304)
# Processed batch 287, features shape: (19881, 2304)
# Processed batch 288, features shape: (21931, 2304)
# Processed batch 289, features shape: (21566, 2304)
# Processed batch 290, features shape: (18624, 2304)
# Processed batch 291, features shape: (14906, 2304)
# Processed batch 292, features shape: (16323, 2304)
# Processed batch 293, features shape: (15685, 2304)
# Processed batch 294, features shape: (16609, 2304)
# Processed batch 295, features shape: (17458, 2304)
# Processed batch 296, features shape: (15350, 2304)
# Processed batch 297, features shape: (17520, 2304)
# Processed batch 298, features shape: (15036, 2304)
# Processed batch 299, features shape: (15613, 2304)
# Processed batch 300, features shape: (15344, 2304)
# Processed batch 301, features shape: (14918, 2304)
# Processed batch 302, features shape: (17684, 2304)
# Processed batch 303, features shape: (19824, 2304)
# Processed batch 304, features shape: (18098, 2304)
# Processed batch 305, features shape: (22660, 2304)
# Processed batch 306, features shape: (21732, 2304)
# Processed batch 307, features shape: (19867, 2304)
# Processed batch 308, features shape: (20545, 2304)
# Processed batch 309, features shape: (17656, 2304)
# Processed batch 310, features shape: (17525, 2304)
# Processed batch 311, features shape: (20921, 2304)
# Processed batch 312, features shape: (20055, 2304)
# Processed batch 313, features shape: (20086, 2304)
# Processed batch 314, features shape: (19621, 2304)
# Processed batch 315, features shape: (20070, 2304)
# Processed batch 316, features shape: (21088, 2304)
# Processed batch 317, features shape: (19730, 2304)
# Processed batch 318, features shape: (20839, 2304)
# Processed batch 319, features shape: (22229, 2304)
# Processed batch 320, features shape: (21670, 2304)
# Processed batch 321, features shape: (19411, 2304)
# Processed batch 322, features shape: (21322, 2304)
# Processed batch 323, features shape: (19523, 2304)
# Processed batch 324, features shape: (19424, 2304)
# Processed batch 325, features shape: (20657, 2304)
# Processed batch 326, features shape: (17399, 2304)
# Processed batch 327, features shape: (20254, 2304)
# Processed batch 328, features shape: (21718, 2304)
# Processed batch 329, features shape: (20179, 2304)
# Processed batch 330, features shape: (19360, 2304)
# Processed batch 331, features shape: (17901, 2304)
# Processed batch 332, features shape: (18468, 2304)
# Processed batch 333, features shape: (19074, 2304)
# Processed batch 334, features shape: (19389, 2304)
# Processed batch 335, features shape: (21575, 2304)
# Processed batch 336, features shape: (19235, 2304)
# Processed batch 337, features shape: (21832, 2304)
# Processed batch 338, features shape: (17927, 2304)
# Processed batch 339, features shape: (16955, 2304)
# Processed batch 340, features shape: (20345, 2304)
# Processed batch 341, features shape: (18572, 2304)
# Processed batch 342, features shape: (16281, 2304)
# Processed batch 343, features shape: (17584, 2304)
# Processed batch 344, features shape: (16176, 2304)
# Processed batch 345, features shape: (18556, 2304)
# Processed batch 346, features shape: (18858, 2304)
# Processed batch 347, features shape: (16221, 2304)
# Processed batch 348, features shape: (16971, 2304)
# Processed batch 349, features shape: (18775, 2304)
# Processed batch 350, features shape: (14790, 2304)
# Processed batch 351, features shape: (19315, 2304)
# Processed batch 352, features shape: (19131, 2304)
# Processed batch 353, features shape: (20484, 2304)
# Processed batch 354, features shape: (20520, 2304)
# Processed batch 355, features shape: (22613, 2304)
# Processed batch 356, features shape: (21742, 2304)
# Processed batch 357, features shape: (19314, 2304)
# Processed batch 358, features shape: (21190, 2304)
# Processed batch 359, features shape: (19569, 2304)
# Processed batch 360, features shape: (20012, 2304)
# Processed batch 361, features shape: (16600, 2304)
# Processed batch 362, features shape: (18430, 2304)
# Processed batch 363, features shape: (18527, 2304)
# Processed batch 364, features shape: (20335, 2304)
# Processed batch 365, features shape: (19642, 2304)
# Processed batch 366, features shape: (21218, 2304)
# Processed batch 367, features shape: (20238, 2304)
# Processed batch 368, features shape: (19606, 2304)
# Processed batch 369, features shape: (19494, 2304)
# Processed batch 370, features shape: (22097, 2304)
# Processed batch 371, features shape: (21873, 2304)
# Processed batch 372, features shape: (21932, 2304)
# Processed batch 373, features shape: (20971, 2304)
# Processed batch 374, features shape: (22969, 2304)
# Processed batch 375, features shape: (18560, 2304)
# Processed batch 376, features shape: (20212, 2304)
# Processed batch 377, features shape: (20318, 2304)
# Processed batch 378, features shape: (19425, 2304)
# Processed batch 379, features shape: (19617, 2304)
# Processed batch 380, features shape: (16118, 2304)
# Processed batch 381, features shape: (16402, 2304)
# Processed batch 382, features shape: (19642, 2304)
# Processed batch 383, features shape: (17632, 2304)
# Processed batch 384, features shape: (20583, 2304)
# Processed batch 385, features shape: (17129, 2304)
# Processed batch 386, features shape: (18310, 2304)
# Processed batch 387, features shape: (21888, 2304)
# Processed batch 388, features shape: (21920, 2304)
# Processed batch 389, features shape: (21779, 2304)
# Processed batch 390, features shape: (21235, 2304)
# Processed batch 391, features shape: (20459, 2304)
# Processed batch 392, features shape: (21835, 2304)
# Processed batch 393, features shape: (20845, 2304)
# Processed batch 394, features shape: (20147, 2304)
# Processed batch 395, features shape: (18605, 2304)
# Processed batch 396, features shape: (16993, 2304)
# Processed batch 397, features shape: (17532, 2304)
# Processed batch 398, features shape: (19332, 2304)
# Processed batch 399, features shape: (20823, 2304)
# Processed batch 400, features shape: (19327, 2304)
# Processed batch 401, features shape: (19997, 2304)
# Processed batch 402, features shape: (15214, 2304)
# Processed batch 403, features shape: (16425, 2304)
# Processed batch 404, features shape: (16694, 2304)
# Processed batch 405, features shape: (19396, 2304)
# Processed batch 406, features shape: (22026, 2304)
# Processed batch 407, features shape: (22296, 2304)
# Processed batch 408, features shape: (21256, 2304)
# Processed batch 409, features shape: (21713, 2304)
# Processed batch 410, features shape: (18953, 2304)
# Processed batch 411, features shape: (20837, 2304)
# Processed batch 412, features shape: (18625, 2304)
# Processed batch 413, features shape: (22681, 2304)
# Processed batch 414, features shape: (18122, 2304)
# Processed batch 415, features shape: (17199, 2304)
# Processed batch 416, features shape: (18813, 2304)
# Processed batch 417, features shape: (18896, 2304)
# Processed batch 418, features shape: (18538, 2304)
# Processed batch 419, features shape: (18314, 2304)
# Processed batch 420, features shape: (20096, 2304)
# Processed batch 421, features shape: (17088, 2304)
# Processed batch 422, features shape: (12864, 2304)
# Processed batch 423, features shape: (11553, 2304)
# Processed batch 424, features shape: (20787, 2304)
# Processed batch 425, features shape: (19763, 2304)
# Processed batch 426, features shape: (18864, 2304)
# Processed batch 427, features shape: (16962, 2304)
# Processed batch 428, features shape: (18369, 2304)
# Processed batch 429, features shape: (20129, 2304)
# Processed batch 430, features shape: (19021, 2304)
# Processed batch 431, features shape: (18718, 2304)
# Processed batch 432, features shape: (18321, 2304)
# Processed batch 433, features shape: (18662, 2304)
# Processed batch 434, features shape: (20492, 2304)
# Processed batch 435, features shape: (17226, 2304)
# Processed batch 436, features shape: (17443, 2304)
# Processed batch 437, features shape: (17359, 2304)
# Processed batch 438, features shape: (17204, 2304)
# Processed batch 439, features shape: (16389, 2304)
# Processed batch 440, features shape: (17313, 2304)
# Processed batch 441, features shape: (19186, 2304)
# Processed batch 442, features shape: (11615, 2304)
# Processed batch 443, features shape: (15888, 2304)
# Processed batch 444, features shape: (15550, 2304)
# Processed batch 445, features shape: (19590, 2304)
# Processed batch 446, features shape: (15643, 2304)
# Processed batch 447, features shape: (19600, 2304)
# Processed batch 448, features shape: (21533, 2304)
# Processed batch 449, features shape: (21249, 2304)
# Processed batch 450, features shape: (21820, 2304)
# Processed batch 451, features shape: (16269, 2304)
# Processed batch 452, features shape: (18490, 2304)
# Processed batch 453, features shape: (16060, 2304)
# Processed batch 454, features shape: (19719, 2304)
# Processed batch 455, features shape: (17277, 2304)
# Processed batch 456, features shape: (17140, 2304)
# Processed batch 457, features shape: (20395, 2304)
# Processed batch 458, features shape: (20166, 2304)
# Processed batch 459, features shape: (19209, 2304)
# Processed batch 460, features shape: (20834, 2304)
# Processed batch 461, features shape: (20842, 2304)
# Processed batch 462, features shape: (19500, 2304)
# Processed batch 463, features shape: (20385, 2304)
# Processed batch 464, features shape: (20606, 2304)
# Processed batch 465, features shape: (17374, 2304)
# Processed batch 466, features shape: (12898, 2304)
# Processed batch 467, features shape: (20840, 2304)
# Processed batch 468, features shape: (21313, 2304)
# Processed batch 469, features shape: (20881, 2304)
# Processed batch 470, features shape: (18661, 2304)
# Processed batch 471, features shape: (18468, 2304)
# Processed batch 472, features shape: (19144, 2304)
# Processed batch 473, features shape: (17127, 2304)
# Processed batch 474, features shape: (17731, 2304)
# Processed batch 475, features shape: (19740, 2304)
# Processed batch 476, features shape: (15410, 2304)
# Processed batch 477, features shape: (18141, 2304)
# Processed batch 478, features shape: (19388, 2304)
# Processed batch 479, features shape: (19847, 2304)
# Processed batch 480, features shape: (19557, 2304)
# Processed batch 481, features shape: (18814, 2304)
# Processed batch 482, features shape: (21376, 2304)
# Processed batch 483, features shape: (19539, 2304)
# Processed batch 484, features shape: (20074, 2304)
# Processed batch 485, features shape: (20642, 2304)
# Processed batch 486, features shape: (21257, 2304)
# Processed batch 487, features shape: (21601, 2304)
# Processed batch 488, features shape: (23235, 2304)
# Processed batch 489, features shape: (22861, 2304)
# Processed batch 490, features shape: (22670, 2304)
# Processed batch 491, features shape: (22552, 2304)
# Processed batch 492, features shape: (20771, 2304)
# Processed batch 493, features shape: (20877, 2304)
# Processed batch 494, features shape: (19845, 2304)
# Processed batch 495, features shape: (18986, 2304)
# Processed batch 496, features shape: (19898, 2304)
# Processed batch 497, features shape: (20084, 2304)
# Processed batch 498, features shape: (17257, 2304)
# Processed batch 499, features shape: (18440, 2304)
# Processed batch 500, features shape: (20005, 2304)
# Processed batch 501, features shape: (18843, 2304)
# Processed batch 502, features shape: (20820, 2304)
# Processed batch 503, features shape: (19954, 2304)
# Processed batch 504, features shape: (18332, 2304)
# Processed batch 505, features shape: (18820, 2304)
# Processed batch 506, features shape: (19994, 2304)
# Processed batch 507, features shape: (15183, 2304)
# Processed batch 508, features shape: (14693, 2304)
# Processed batch 509, features shape: (17520, 2304)
# Processed batch 510, features shape: (21407, 2304)
# Processed batch 511, features shape: (19828, 2304)
# Processed batch 512, features shape: (16971, 2304)
# Processed batch 513, features shape: (22011, 2304)
# Processed batch 514, features shape: (20101, 2304)
# Processed batch 515, features shape: (20505, 2304)
# Processed batch 516, features shape: (21570, 2304)
# Processed batch 517, features shape: (20612, 2304)
# Processed batch 518, features shape: (21317, 2304)
# Processed batch 519, features shape: (19374, 2304)
# Processed batch 520, features shape: (21652, 2304)
# Processed batch 521, features shape: (13665, 2304)
# Processed batch 522, features shape: (18519, 2304)
# Processed batch 523, features shape: (19480, 2304)
# Processed batch 524, features shape: (20960, 2304)
# Processed batch 525, features shape: (20398, 2304)
# Processed batch 526, features shape: (21764, 2304)
# Processed batch 527, features shape: (18751, 2304)
# Processed batch 528, features shape: (19632, 2304)
# Processed batch 529, features shape: (17812, 2304)
# Processed batch 530, features shape: (15779, 2304)
# Processed batch 531, features shape: (15190, 2304)
# Processed batch 532, features shape: (14710, 2304)
# Processed batch 533, features shape: (13323, 2304)
# Processed batch 534, features shape: (15280, 2304)
# Processed batch 535, features shape: (15496, 2304)
# Processed batch 536, features shape: (17729, 2304)
# Processed batch 537, features shape: (19996, 2304)
# Processed batch 538, features shape: (19982, 2304)
# Processed batch 539, features shape: (19177, 2304)
# Processed batch 540, features shape: (20291, 2304)
# Processed batch 541, features shape: (17269, 2304)
# Processed batch 542, features shape: (19863, 2304)
# Processed batch 543, features shape: (19207, 2304)
# Processed batch 544, features shape: (21797, 2304)
# Processed batch 545, features shape: (22194, 2304)
# Processed batch 546, features shape: (19614, 2304)
# Processed batch 547, features shape: (18619, 2304)
# Processed batch 548, features shape: (19006, 2304)
# Processed batch 549, features shape: (19503, 2304)
# Processed batch 550, features shape: (20485, 2304)
# Processed batch 551, features shape: (21285, 2304)
# Processed batch 552, features shape: (21063, 2304)
# Processed batch 553, features shape: (22487, 2304)
# Processed batch 554, features shape: (21391, 2304)
# Processed batch 555, features shape: (17502, 2304)
# Processed batch 556, features shape: (21249, 2304)
# Processed batch 557, features shape: (22340, 2304)
# Processed batch 558, features shape: (21296, 2304)
# Processed batch 559, features shape: (20627, 2304)
# Processed batch 560, features shape: (21042, 2304)
# Processed batch 561, features shape: (22370, 2304)
# Processed batch 562, features shape: (21464, 2304)
# Processed batch 563, features shape: (19708, 2304)
# Processed batch 564, features shape: (19142, 2304)
# Processed batch 565, features shape: (19679, 2304)
# Processed batch 566, features shape: (21407, 2304)
# Processed batch 567, features shape: (18333, 2304)
# Processed batch 568, features shape: (19455, 2304)
# Processed batch 569, features shape: (20697, 2304)
# Processed batch 570, features shape: (21536, 2304)
# Processed batch 571, features shape: (18984, 2304)
# Processed batch 572, features shape: (21307, 2304)
# Processed batch 573, features shape: (18526, 2304)
# Processed batch 574, features shape: (16753, 2304)
# Processed batch 575, features shape: (19343, 2304)
# Processed batch 576, features shape: (20031, 2304)
# Processed batch 577, features shape: (21119, 2304)
# Processed batch 578, features shape: (21928, 2304)
# Processed batch 579, features shape: (22829, 2304)
# Processed batch 580, features shape: (19580, 2304)
# Processed batch 581, features shape: (21765, 2304)
# Processed batch 582, features shape: (21240, 2304)
# Processed batch 583, features shape: (20509, 2304)
# Processed batch 584, features shape: (19114, 2304)
# Processed batch 585, features shape: (20767, 2304)
# Processed batch 586, features shape: (21476, 2304)
# Processed batch 587, features shape: (21739, 2304)
# Processed batch 588, features shape: (20286, 2304)
# Processed batch 589, features shape: (17412, 2304)
# Processed batch 590, features shape: (18790, 2304)
# Processed batch 591, features shape: (15978, 2304)
# Processed batch 592, features shape: (18442, 2304)
# Processed batch 593, features shape: (18957, 2304)
# Processed batch 594, features shape: (19587, 2304)
# Processed batch 595, features shape: (20173, 2304)
# Processed batch 596, features shape: (17684, 2304)
# Processed batch 597, features shape: (17923, 2304)
# Processed batch 598, features shape: (18764, 2304)
# Processed batch 599, features shape: (17946, 2304)
# Processed batch 600, features shape: (17449, 2304)
# Processed batch 601, features shape: (14152, 2304)
# Processed batch 602, features shape: (19050, 2304)
# Processed batch 603, features shape: (19770, 2304)
# Processed batch 604, features shape: (19248, 2304)
# Processed batch 605, features shape: (20399, 2304)
# Processed batch 606, features shape: (20391, 2304)
# Processed batch 607, features shape: (21618, 2304)
# Processed batch 608, features shape: (20694, 2304)
# Processed batch 609, features shape: (21172, 2304)
# Processed batch 610, features shape: (20694, 2304)
# Processed batch 611, features shape: (20798, 2304)
# Processed batch 612, features shape: (15864, 2304)
# Processed batch 613, features shape: (15587, 2304)
# Processed batch 614, features shape: (16713, 2304)
# Processed batch 615, features shape: (20500, 2304)
# Processed batch 616, features shape: (18747, 2304)
# Processed batch 617, features shape: (16969, 2304)
# Processed batch 618, features shape: (19118, 2304)
# Processed batch 619, features shape: (20014, 2304)
# Processed batch 620, features shape: (20529, 2304)
# Processed batch 621, features shape: (15027, 2304)
# Processed batch 622, features shape: (15854, 2304)
# Processed batch 623, features shape: (13832, 2304)
# Processed batch 624, features shape: (16361, 2304)
# Processed batch 625, features shape: (18141, 2304)
# Processed batch 626, features shape: (17389, 2304)
# Processed batch 627, features shape: (19403, 2304)
# Processed batch 628, features shape: (17837, 2304)
# Processed batch 629, features shape: (20612, 2304)
# Processed batch 630, features shape: (19540, 2304)
# Processed batch 631, features shape: (21969, 2304)
# Processed batch 632, features shape: (21709, 2304)
# Processed batch 633, features shape: (19601, 2304)
# Processed batch 634, features shape: (21036, 2304)
# Processed batch 635, features shape: (20999, 2304)
# Processed batch 636, features shape: (20739, 2304)
# Processed batch 637, features shape: (21560, 2304)
# Processed batch 638, features shape: (18783, 2304)
# Processed batch 639, features shape: (18619, 2304)
# Processed batch 640, features shape: (15875, 2304)
# Processed batch 641, features shape: (17630, 2304)
# Processed batch 642, features shape: (18491, 2304)
# Processed batch 643, features shape: (19048, 2304)
# Processed batch 644, features shape: (20963, 2304)
# Processed batch 645, features shape: (17859, 2304)
# Processed batch 646, features shape: (18720, 2304)
# Processed batch 647, features shape: (20734, 2304)
# Processed batch 648, features shape: (20665, 2304)
# Processed batch 649, features shape: (20588, 2304)
# Processed batch 650, features shape: (19964, 2304)
# Processed batch 651, features shape: (20763, 2304)
# Processed batch 652, features shape: (22072, 2304)
# Processed batch 653, features shape: (20677, 2304)
# Processed batch 654, features shape: (21689, 2304)
# Processed batch 655, features shape: (22907, 2304)
# Processed batch 656, features shape: (21378, 2304)
# Processed batch 657, features shape: (23164, 2304)
# Processed batch 658, features shape: (19234, 2304)
# Processed batch 659, features shape: (20414, 2304)
# Processed batch 660, features shape: (21366, 2304)
# Processed batch 661, features shape: (14536, 2304)
# Processed batch 662, features shape: (17448, 2304)
# Processed batch 663, features shape: (15979, 2304)
# Processed batch 664, features shape: (20007, 2304)
# Processed batch 665, features shape: (19788, 2304)
# Processed batch 666, features shape: (19681, 2304)
# Processed batch 667, features shape: (20566, 2304)
# Processed batch 668, features shape: (16940, 2304)
# Processed batch 669, features shape: (18587, 2304)
# Processed batch 670, features shape: (19917, 2304)
# Processed batch 671, features shape: (21459, 2304)
# Processed batch 672, features shape: (19614, 2304)
# Processed batch 673, features shape: (20035, 2304)
# Processed batch 674, features shape: (18812, 2304)
# Processed batch 675, features shape: (21953, 2304)
# Processed batch 676, features shape: (19326, 2304)
# Processed batch 677, features shape: (22668, 2304)
# Processed batch 678, features shape: (20350, 2304)
# Processed batch 679, features shape: (21361, 2304)
# Processed batch 680, features shape: (21718, 2304)
# Processed batch 681, features shape: (22350, 2304)
# Processed batch 682, features shape: (20624, 2304)
# Processed batch 683, features shape: (21991, 2304)
# Processed batch 684, features shape: (19610, 2304)
# Processed batch 685, features shape: (20291, 2304)
# Processed batch 686, features shape: (19953, 2304)
# Processed batch 687, features shape: (18858, 2304)
# Processed batch 688, features shape: (20461, 2304)
# Processed batch 689, features shape: (21801, 2304)
# Processed batch 690, features shape: (18000, 2304)
# Processed batch 691, features shape: (18886, 2304)
# Processed batch 692, features shape: (19357, 2304)
# Processed batch 693, features shape: (15918, 2304)
# Processed batch 694, features shape: (14725, 2304)
# Processed batch 695, features shape: (17038, 2304)
# Processed batch 696, features shape: (15345, 2304)
# Processed batch 697, features shape: (16903, 2304)
# Processed batch 698, features shape: (16837, 2304)
# Processed batch 699, features shape: (16270, 2304)
# Processed batch 700, features shape: (16461, 2304)
# Processed batch 701, features shape: (18636, 2304)
# Processed batch 702, features shape: (15924, 2304)
# Processed batch 703, features shape: (18035, 2304)
# Processed batch 704, features shape: (17138, 2304)
# Processed batch 705, features shape: (14007, 2304)
# Processed batch 706, features shape: (18410, 2304)
# Processed batch 707, features shape: (18984, 2304)
# Processed batch 708, features shape: (18102, 2304)
# Processed batch 709, features shape: (18766, 2304)
# Processed batch 710, features shape: (15713, 2304)
# Processed batch 711, features shape: (15891, 2304)
# Processed batch 712, features shape: (17259, 2304)
# Processed batch 713, features shape: (20045, 2304)
# Processed batch 714, features shape: (21948, 2304)
# Processed batch 715, features shape: (19158, 2304)
# Processed batch 716, features shape: (19556, 2304)
# Processed batch 717, features shape: (19261, 2304)
# Processed batch 718, features shape: (17882, 2304)
# Processed batch 719, features shape: (18461, 2304)
# Processed batch 720, features shape: (19784, 2304)
# Processed batch 721, features shape: (18522, 2304)
# Processed batch 722, features shape: (18909, 2304)
# Processed batch 723, features shape: (19365, 2304)
# Processed batch 724, features shape: (17326, 2304)
# Processed batch 725, features shape: (21453, 2304)
# Processed batch 726, features shape: (20836, 2304)
# Processed batch 727, features shape: (22770, 2304)
# Processed batch 728, features shape: (22119, 2304)
# Processed batch 729, features shape: (21835, 2304)
# Processed batch 730, features shape: (21037, 2304)
# Processed batch 731, features shape: (20569, 2304)
# Processed batch 732, features shape: (17600, 2304)
# Processed batch 733, features shape: (19609, 2304)
# Processed batch 734, features shape: (19499, 2304)
# Processed batch 735, features shape: (22736, 2304)
# Processed batch 736, features shape: (20631, 2304)
# Processed batch 737, features shape: (22492, 2304)
# Processed batch 738, features shape: (19430, 2304)
# Processed batch 739, features shape: (17436, 2304)
# Processed batch 740, features shape: (17773, 2304)
# Processed batch 741, features shape: (18115, 2304)
# Processed batch 742, features shape: (17192, 2304)
# Processed batch 743, features shape: (17732, 2304)
# Processed batch 744, features shape: (17849, 2304)
# Processed batch 745, features shape: (18241, 2304)
# Processed batch 746, features shape: (19101, 2304)
# Processed batch 747, features shape: (19405, 2304)
# Processed batch 748, features shape: (17829, 2304)
# Processed batch 749, features shape: (16280, 2304)
# Processed batch 750, features shape: (17849, 2304)
# Processed batch 751, features shape: (14074, 2304)
# Processed batch 752, features shape: (13896, 2304)
# Processed batch 753, features shape: (20014, 2304)
# Processed batch 754, features shape: (22580, 2304)
# Processed batch 755, features shape: (20602, 2304)
# Processed batch 756, features shape: (18985, 2304)
# Processed batch 757, features shape: (15862, 2304)
# Processed batch 758, features shape: (16641, 2304)
# Processed batch 759, features shape: (17895, 2304)
# Processed batch 760, features shape: (18942, 2304)
# Processed batch 761, features shape: (21075, 2304)
# Processed batch 762, features shape: (21256, 2304)
# Processed batch 763, features shape: (19988, 2304)
# Processed batch 764, features shape: (20473, 2304)
# Processed batch 765, features shape: (22921, 2304)
# Processed batch 766, features shape: (21754, 2304)
# Processed batch 767, features shape: (19679, 2304)
# Processed batch 768, features shape: (21060, 2304)
# Processed batch 769, features shape: (18456, 2304)
# Processed batch 770, features shape: (18205, 2304)
# Processed batch 771, features shape: (18295, 2304)
# Processed batch 772, features shape: (20534, 2304)
# Processed batch 773, features shape: (18835, 2304)
# Processed batch 774, features shape: (20243, 2304)
# Processed batch 775, features shape: (18323, 2304)
# Processed batch 776, features shape: (20435, 2304)
# Processed batch 777, features shape: (20432, 2304)
# Processed batch 778, features shape: (23027, 2304)
# Processed batch 779, features shape: (21306, 2304)
# Processed batch 780, features shape: (19768, 2304)
# Processed batch 781, features shape: (20654, 2304)
# Processed batch 782, features shape: (19446, 2304)
# Processed batch 783, features shape: (19025, 2304)
# Processed batch 784, features shape: (17894, 2304)
# Processed batch 785, features shape: (18807, 2304)
# Processed batch 786, features shape: (22077, 2304)
# Processed batch 787, features shape: (20146, 2304)
# Processed batch 788, features shape: (21165, 2304)
# Processed batch 789, features shape: (19503, 2304)
# Processed batch 790, features shape: (22044, 2304)
# Processed batch 791, features shape: (19069, 2304)
# Processed batch 792, features shape: (19951, 2304)
# Processed batch 793, features shape: (18979, 2304)
# Processed batch 794, features shape: (17458, 2304)
# Processed batch 795, features shape: (16897, 2304)
# Processed batch 796, features shape: (16333, 2304)
# Processed batch 797, features shape: (17992, 2304)
# Processed batch 798, features shape: (17194, 2304)
# Processed batch 799, features shape: (19926, 2304)
# Processed batch 800, features shape: (21410, 2304)
# Processed batch 801, features shape: (22955, 2304)
# Processed batch 802, features shape: (20569, 2304)
# Processed batch 803, features shape: (18370, 2304)
# Processed batch 804, features shape: (12158, 2304)
# Processed batch 805, features shape: (11831, 2304)
# Processed batch 806, features shape: (14708, 2304)
# Processed batch 807, features shape: (16180, 2304)
# Processed batch 808, features shape: (18827, 2304)
# Processed batch 809, features shape: (18892, 2304)
# Processed batch 810, features shape: (18020, 2304)
# Processed batch 811, features shape: (20533, 2304)
# Processed batch 812, features shape: (15931, 2304)
# Processed batch 813, features shape: (14176, 2304)
# Processed batch 814, features shape: (20197, 2304)
# Processed batch 815, features shape: (18709, 2304)
# Processed batch 816, features shape: (20327, 2304)
# Processed batch 817, features shape: (21222, 2304)
# Processed batch 818, features shape: (21533, 2304)
# Processed batch 819, features shape: (20392, 2304)
# Processed batch 820, features shape: (20227, 2304)
# Processed batch 821, features shape: (22018, 2304)
# Processed batch 822, features shape: (19211, 2304)
# Processed batch 823, features shape: (21208, 2304)
# Processed batch 824, features shape: (17952, 2304)
# Processed batch 825, features shape: (20666, 2304)
# Processed batch 826, features shape: (19735, 2304)
# Processed batch 827, features shape: (21238, 2304)
# Processed batch 828, features shape: (20036, 2304)
# Processed batch 829, features shape: (20768, 2304)
# Processed batch 830, features shape: (20548, 2304)
# Processed batch 831, features shape: (20007, 2304)
# Processed batch 832, features shape: (21569, 2304)
# Processed batch 833, features shape: (20400, 2304)
# Processed batch 834, features shape: (19949, 2304)
# Processed batch 835, features shape: (20212, 2304)
# Processed batch 836, features shape: (20789, 2304)
# Processed batch 837, features shape: (19319, 2304)
# Processed batch 838, features shape: (20700, 2304)
# Processed batch 839, features shape: (22986, 2304)
# Processed batch 840, features shape: (20298, 2304)
# Processed batch 841, features shape: (21591, 2304)
# Processed batch 842, features shape: (19959, 2304)
# Processed batch 843, features shape: (19201, 2304)
# Processed batch 844, features shape: (20313, 2304)
# Processed batch 845, features shape: (20589, 2304)
# Processed batch 846, features shape: (20599, 2304)
# Processed batch 847, features shape: (18166, 2304)
# Processed batch 848, features shape: (21318, 2304)
# Processed batch 849, features shape: (19181, 2304)
# Processed batch 850, features shape: (19646, 2304)
# Processed batch 851, features shape: (19755, 2304)
# Processed batch 852, features shape: (21568, 2304)
# Processed batch 853, features shape: (19685, 2304)
# Processed batch 854, features shape: (19983, 2304)
# Processed batch 855, features shape: (15307, 2304)
# Processed batch 856, features shape: (14931, 2304)
# Processed batch 857, features shape: (18374, 2304)
# Processed batch 858, features shape: (20171, 2304)
# Processed batch 859, features shape: (19208, 2304)
# Processed batch 860, features shape: (19356, 2304)
# Processed batch 861, features shape: (20227, 2304)
# Processed batch 862, features shape: (19325, 2304)
# Processed batch 863, features shape: (18336, 2304)
# Processed batch 864, features shape: (20254, 2304)
# Processed batch 865, features shape: (19596, 2304)
# Processed batch 866, features shape: (19789, 2304)
# Processed batch 867, features shape: (21300, 2304)
# Processed batch 868, features shape: (21146, 2304)
# Processed batch 869, features shape: (20134, 2304)
# Processed batch 870, features shape: (20626, 2304)
# Processed batch 871, features shape: (16778, 2304)
# Processed batch 872, features shape: (17125, 2304)
# Processed batch 873, features shape: (20354, 2304)
# Processed batch 874, features shape: (17315, 2304)
# Processed batch 875, features shape: (16813, 2304)
# Processed batch 876, features shape: (16000, 2304)
# Processed batch 877, features shape: (18265, 2304)
# Processed batch 878, features shape: (18872, 2304)
# Processed batch 879, features shape: (17610, 2304)
# Processed batch 880, features shape: (18790, 2304)
# Processed batch 881, features shape: (18722, 2304)
# Processed batch 882, features shape: (17845, 2304)
# Processed batch 883, features shape: (20309, 2304)
# Processed batch 884, features shape: (20118, 2304)
# Processed batch 885, features shape: (21792, 2304)
# Processed batch 886, features shape: (18657, 2304)
# Processed batch 887, features shape: (19940, 2304)
# Processed batch 888, features shape: (19063, 2304)
# Processed batch 889, features shape: (19228, 2304)
# Processed batch 890, features shape: (20725, 2304)
# Processed batch 891, features shape: (16020, 2304)
# Processed batch 892, features shape: (13997, 2304)
# Processed batch 893, features shape: (15902, 2304)
# Processed batch 894, features shape: (17090, 2304)
# Processed batch 895, features shape: (21157, 2304)
# Processed batch 896, features shape: (19958, 2304)
# Processed batch 897, features shape: (19942, 2304)
# Processed batch 898, features shape: (17082, 2304)
# Processed batch 899, features shape: (20555, 2304)
# Processed batch 900, features shape: (12041, 2304)
# Processed batch 901, features shape: (18891, 2304)
# Processed batch 902, features shape: (20736, 2304)
# Processed batch 903, features shape: (17592, 2304)
# Processed batch 904, features shape: (17258, 2304)
# Processed batch 905, features shape: (16320, 2304)
# Processed batch 906, features shape: (17163, 2304)
# Processed batch 907, features shape: (16948, 2304)
# Processed batch 908, features shape: (21341, 2304)
# Processed batch 909, features shape: (22587, 2304)
# Processed batch 910, features shape: (18221, 2304)
# Processed batch 911, features shape: (19549, 2304)
# Processed batch 912, features shape: (20402, 2304)
# Processed batch 913, features shape: (20453, 2304)
# Processed batch 914, features shape: (20112, 2304)
# Processed batch 915, features shape: (19521, 2304)
# Processed batch 916, features shape: (18473, 2304)
# Processed batch 917, features shape: (19472, 2304)
# Processed batch 918, features shape: (14430, 2304)
# Processed batch 919, features shape: (15576, 2304)
# Processed batch 920, features shape: (18230, 2304)
# Processed batch 921, features shape: (17979, 2304)
# Processed batch 922, features shape: (22400, 2304)
# Processed batch 923, features shape: (21142, 2304)
# Processed batch 924, features shape: (19036, 2304)
# Processed batch 925, features shape: (20832, 2304)
# Processed batch 926, features shape: (20501, 2304)
# Processed batch 927, features shape: (18223, 2304)
# Processed batch 928, features shape: (21156, 2304)
# Processed batch 929, features shape: (20701, 2304)
# Processed batch 930, features shape: (22172, 2304)
# Processed batch 931, features shape: (20061, 2304)
# Processed batch 932, features shape: (19800, 2304)
# Processed batch 933, features shape: (16050, 2304)
# Processed batch 934, features shape: (19346, 2304)
# Processed batch 935, features shape: (17248, 2304)
# Processed batch 936, features shape: (20093, 2304)
# Processed batch 937, features shape: (17650, 2304)
# Processed batch 938, features shape: (16667, 2304)
# Processed batch 939, features shape: (16755, 2304)
# Processed batch 940, features shape: (13886, 2304)
# Processed batch 941, features shape: (17990, 2304)
# Processed batch 942, features shape: (16637, 2304)
# Processed batch 943, features shape: (17032, 2304)
# Processed batch 944, features shape: (17603, 2304)
# Processed batch 945, features shape: (18798, 2304)
# Processed batch 946, features shape: (18733, 2304)
# Processed batch 947, features shape: (17254, 2304)
# Processed batch 948, features shape: (20639, 2304)
# Processed batch 949, features shape: (19462, 2304)
# Processed batch 950, features shape: (16985, 2304)
# Processed batch 951, features shape: (16516, 2304)
# Processed batch 952, features shape: (19547, 2304)
# Processed batch 953, features shape: (18622, 2304)
# Processed batch 954, features shape: (16236, 2304)
# Processed batch 955, features shape: (18018, 2304)
# Processed batch 956, features shape: (19313, 2304)
# Processed batch 957, features shape: (17892, 2304)
# Processed batch 958, features shape: (17632, 2304)
# Processed batch 959, features shape: (19719, 2304)
# Processed batch 960, features shape: (15407, 2304)
# Processed batch 961, features shape: (17503, 2304)
# Processed batch 962, features shape: (21391, 2304)
# Processed batch 963, features shape: (21536, 2304)
# Processed batch 964, features shape: (22046, 2304)
# Processed batch 965, features shape: (19607, 2304)
# Processed batch 966, features shape: (19808, 2304)
# Processed batch 967, features shape: (20982, 2304)
# Processed batch 968, features shape: (21940, 2304)
# Processed batch 969, features shape: (22204, 2304)
# Processed batch 970, features shape: (19718, 2304)
# Processed batch 971, features shape: (16855, 2304)
# Processed batch 972, features shape: (15547, 2304)
# Processed batch 973, features shape: (16395, 2304)
# Processed batch 974, features shape: (18458, 2304)
# Processed batch 975, features shape: (18519, 2304)
# Processed batch 976, features shape: (18524, 2304)
# Processed batch 977, features shape: (21464, 2304)
# Processed batch 978, features shape: (16333, 2304)
# Processed batch 979, features shape: (21033, 2304)
# Processed batch 980, features shape: (19299, 2304)
# Processed batch 981, features shape: (17947, 2304)
# Processed batch 982, features shape: (18890, 2304)
# Processed batch 983, features shape: (19452, 2304)
# Processed batch 984, features shape: (15428, 2304)
# Processed batch 985, features shape: (19566, 2304)
# Processed batch 986, features shape: (18165, 2304)
# Processed batch 987, features shape: (20659, 2304)
# Processed batch 988, features shape: (20051, 2304)
# Processed batch 989, features shape: (20291, 2304)
# Processed batch 990, features shape: (22077, 2304)
# Processed batch 991, features shape: (21017, 2304)
# Processed batch 992, features shape: (19403, 2304)
# Processed batch 993, features shape: (22163, 2304)
# Processed batch 994, features shape: (19954, 2304)
# Processed batch 995, features shape: (17693, 2304)
# Processed batch 996, features shape: (21831, 2304)
# Processed batch 997, features shape: (22982, 2304)
# Processed batch 998, features shape: (18517, 2304)
# Processed batch 999, features shape: (18633, 2304)
# Processed batch 1000, features shape: (19471, 2304)
# Reached max batch limit. Stopping early.

# %%
'''
# Save model
save_path = "/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/script/train_classifier/kmeans_model_500.pkl"
from joblib import dump
dump(kmeans, save_path)
print(f"KMeans model saved to {save_path}")
'''
# Out:
# KMeans model saved to /mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/script/train_classifier/kmeans_model_500.pkl

# %% [markdown]
# #### Test if sucessfully saved

# %%
'''
import joblib
from sklearn.cluster import MiniBatchKMeans

kmeans = joblib.load("/mnt/scratch/pippalin2/jupyter/GMM-DistilHuBERT/script/train_classifier/kmeans_model_500.pkl")
print("Cluster centers shape:", kmeans.cluster_centers_.shape)
'''
# Out:
# Cluster centers shape: (500, 2304)

# %%
'''
# Sample audio → model → features → cluster IDs
input_values = processor(example["audio"]["array"], sampling_rate=16000, return_tensors="pt").input_values.to(device)
features = extract_all_layer_features(model, input_values, layers=[0, 1, 2])
feats_np = features.squeeze(0).cpu().numpy()  # shape [T, D]

cluster_ids = kmeans.predict(feats_np)  # shape [T]
print("Cluster IDs:", cluster_ids[:20])
'''
# Out:
# Cluster IDs: [156 156 377 377 377 377  69  69  69  69  69  69  69  69 411 411 411 411
#  411 105]
